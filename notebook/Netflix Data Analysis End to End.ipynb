# %%
import pandas as pd
df = pd.read_csv('netflix_titles.csv', encoding = "utf-8")

# %%
import sqlalchemy as sal
engine = sal.create_engine('mssql://mahima\MSSQLSERVER2025/master?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
conn = engine.connect()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16744\1655752075.py:3: SAWarning: Unrecognized server version info '17.0.1105.2'.  Some SQL Server features may not function properly.
#   conn = engine.connect()

# %%
print(conn)

# %%
from sqlalchemy import create_engine, NVARCHAR
df.to_sql('netflix_raw', index = False, con = conn, if_exists = 'replace',dtype={"title": NVARCHAR(200)})
# Out:
# 107

# %%
len(df)
# Out:
# 8807

# %%
df[df.show_id=='s5023']
# Out:
#      show_id   type    title       director           cast      country  \
# 5022   s5023  Movie  반드시 잡는다  Hong-seon Kim  Baek Yoon-sik  South Korea
#
#              date_added  release_year rating duration  \
# 5022  February 28, 2018          2017  TV-MA  110 min
#
#                                     listed_in  \
# 5022  Dramas, International Movies, Thrillers
#
#                                             description
# 5022  After people in his town start turning up dead...

# %%
max(df.director.str.len())
# Out:
# 208.0

# %%
max(df.description.dropna().str.len())
# Out:
# 248

# %%
print(df.title.head())
# Out:
# 0     Dick Johnson Is Dead
# 1            Blood & Water
# 2                Ganglands
# 3    Jailbirds New Orleans
# 4             Kota Factory
# Name: title, dtype: object

# %%
print(df['title'].head())
# Out:
# 0     Dick Johnson Is Dead
# 1            Blood & Water
# 2                Ganglands
# 3    Jailbirds New Orleans
# 4             Kota Factory
# Name: title, dtype: object

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
len(df)
# Out:
# 8807
